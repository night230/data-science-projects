# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/sanyamdhadiwal2302/netflix-data/mymoviedb.csv

# %%
import pandas as pd
import os
os.listdir()
df = pd.read_csv(
    '/kaggle/input/datasets/sanyamdhadiwal2302/netflix-data/mymoviedb.csv',
    engine='python'
)

df.head(1)
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
#
#                                           Poster_Url
# 0  https://image.tmdb.org/t/p/original/1g0dhYtq4i...

# %%
df.isnull()
# Out:
#       Release_Date  Title  Overview  Popularity  Vote_Count  Vote_Average  \
# 0            False  False     False       False       False         False
# 1            False  False     False       False       False         False
# 2            False  False     False       False       False         False
# 3            False  False     False       False       False         False
# 4            False  False     False       False       False         False
# ...            ...    ...       ...         ...         ...           ...
# 9832         False  False     False       False       False         False
# 9833         False  False     False       False       False         False
# 9834         False  False     False       False       False         False
# 9835         False  False     False       False       False         False
# 9836         False  False     False       False       False         False
#
#       Original_Language  Genre  Poster_Url
# ...

# %%
df.isnull().sum()
# Out:
# Release_Date          0
# Title                 9
# Overview              9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# Poster_Url           11
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9832    0
# 9833    0
# 9834    0
# 9835    0
# 9836    0
# Length: 9837, dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Release_Date          0
# Title                 9
# Overview              9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# Poster_Url           11
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9826 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9826 non-null   object
#  1   Title              9826 non-null   object
#  2   Overview           9826 non-null   object
#  3   Popularity         9826 non-null   float64
#  4   Vote_Count         9826 non-null   object
#  5   Vote_Average       9826 non-null   object
#  6   Original_Language  9826 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 767.7+ KB

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9826 entries, 0 to 9825
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9826 non-null   object
#  1   Title              9826 non-null   object
#  2   Overview           9826 non-null   object
#  3   Popularity         9826 non-null   float64
#  4   Vote_Count         9826 non-null   object
#  5   Vote_Average       9826 non-null   object
#  6   Original_Language  9826 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.0+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9821    False
# 9822    False
# 9823    False
# 9824    False
# 9825    False
# Length: 9826, dtype: bool

# %%
df['Vote_Count'] = df['Vote_Count'].astype('float64')
df['Vote_Average'] = df['Vote_Average'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9826 entries, 0 to 9825
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9826 non-null   object
#  1   Title              9826 non-null   object
#  2   Overview           9826 non-null   object
#  3   Popularity         9826 non-null   float64
#  4   Vote_Count         9826 non-null   float64
#  5   Vote_Average       9826 non-null   float64
#  6   Original_Language  9826 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 691.0+ KB

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9826.000000   9826.000000   9826.000000
# mean     40.323951   1392.943721      6.439467
# std     108.879332   2611.303856      1.129797
# min      13.354000      0.000000      0.000000
# 25%      16.128250    146.000000      5.900000
# 50%      21.195000    444.000000      6.500000
# 75%      35.179250   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
df.sort_values(by='Vote_Average', ascending=False).head()
# Out:
#      Release_Date                                          Title  \
# 9390   2020-04-09                     Kung Fu Master Huo Yuanjia
# 7338   2018-06-08              Franco Escamilla: Por La Anécdota
# 667    2019-03-29  Demon Slayer: Kimetsu no Yaiba Sibling's Bond
# 2324   2021-06-17                              Impossible Things
# 7400   2020-10-30                                    My Sex Doll
#
#                                                Overview  Popularity  \
# 9390  The young and vigorous Huo Yuanjia was only fo...      13.745
# 7338  Mexican stand-up comedian Franco Escamilla dra...      16.158
# 667   Tanjiro finds his family slaughtered and the l...      86.689
# 2324  A widow who is tormented by the memory of her ...      36.466
# 7400  The story of chaos both body and mind occurs w...      16.088
#
#       Vote_Count  Vote_Average Original_Language                       Genre  \
# 9390         1.0          10.0                zh               Action, Drama
# ...

# %%
df.sort_values(by='Vote_Average', ascending=True).head()
# Out:
#      Release_Date                                           Title  \
# 917    2022-10-07  Spider-Man: Across the Spider-Verse (Part One)
# 9133   2023-05-24                              The Little Mermaid
# 4852   2018-06-07                            Nice Sister-In-Law 3
# 8467   2022-08-24                    Puss in Boots: The Last Wish
# 1212   2022-03-16                                       Ambulance
#
#                                                Overview  Popularity  \
# 917   Miles Morales returns for the next chapter of ...      69.174
# 9133  A young mermaid makes a deal with a sea witch:...      14.016
# 4852  Jung-tae has become a successful businessman. ...      21.352
# 8467  Puss in Boots discovers that his passion for a...      14.687
# 1212  Decorated veteran Will Sharp, desperate for mo...      57.956
#
#       Vote_Count  Vote_Average Original_Language  \
# 917          0.0           0.0                en
# 9133         0.0           0.0                en
# ...

# %%
df.sort_values(by='Popularity', ascending=False).head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.sort_values(by='Popularity', ascending=True).head()
# Out:
#      Release_Date                                 Title  \
# 9825   1984-09-23                               Threads
# 9824   2021-03-31  The United States vs. Billie Holiday
# 9823   2016-05-06                          The Offering
# 9822   2020-10-01                      Violent Delights
# 9820   1974-11-06                     The Little Prince
#
#                                                Overview  Popularity  \
# 9825  Documentary style account of a nuclear holocau...      13.354
# 9824  Billie Holiday spent much of her career being ...      13.354
# 9823  When young and successful reporter Jamie finds...      13.355
# 9822  A female vampire falls in love with a man she ...      13.356
# 9820  Based on the story by Antoine deSaint-Exupery,...      13.357
#
#       Vote_Count  Vote_Average Original_Language  \
# 9825       186.0           7.8                en
# 9824       152.0           6.7                en
# 9823        94.0           5.0                en
# ...

# %%
df.sort_values(by='Vote_Count', ascending=False).head()
# Out:
#     Release_Date            Title  \
# 380   2010-07-15        Inception
# 461   2014-11-05     Interstellar
# 221   2008-07-14  The Dark Knight
# 138   2012-04-25     The Avengers
# 195   2016-02-09         Deadpool
#
#                                               Overview  Popularity  \
# 380  Cobb, a skilled thief who commits corporate es...     127.131
# 461  The adventures of a group of explorers who mak...     110.531
# 221  Batman raises the stakes in his war on crime. ...     173.923
# 138  When an unexpected enemy emerges and threatens...     229.772
# 195  Deadpool tells the origin story of former Spec...     189.206
#
#      Vote_Count  Vote_Average Original_Language  \
# 380     31077.0           8.4                en
# 461     27975.0           8.4                en
# 221     26994.0           8.5                en
# 138     26490.0           7.7                en
# 195     26390.0           7.6                en
#
#                                   Genre  \
# ...

# %%
df.sort_values(by='Vote_Count', ascending=True).head()
# Out:
#      Release_Date                    Title  \
# 6484   2023-02-15              The Marvels
# 6938   2021-07-13  Deadpool and Korg React
# 6437   2022-03-25           Infinite Storm
# 6422   2022-03-10               Madu Murni
# 6951   2022-03-11                Offseason
#
#                                                Overview  Popularity  \
# 6484               The sequel to Captain Marvel (2019).      17.592
# 6938  Two members of the MCYouTube react to the upco...      16.806
# 6437  One woman's journey for self-discovery and tur...      17.676
# 6422                                      Plot unknown.      17.697
# 6951  Upon receiving a mysterious letter that her mo...      16.783
#
#       Vote_Count  Vote_Average Original_Language  \
# 6484         0.0           0.0                en
# 6938         0.0           0.0                en
# 6437         0.0           0.0                en
# 6422         0.0           0.0                id
# ...

# %%
df.to_csv("Netflix_data_cleaning.csv", index=False)

# %%
df.to_csv("file.csv", index=False)

# %%
df.to_excel("Netflix_data_cleaning.xlsx", index=False)
