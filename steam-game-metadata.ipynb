# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/newnguyn/steam-game-clean/SteamGames.csv
# /kaggle/input/datasets/newnguyn/steam-game-clean/SteamGames_cleaned.csv

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("/kaggle/input/datasets/newnguyn/steam-game-clean/SteamGames.csv")

df.head(1)
# Out:
#      Appid                   Name  Type   ReleaseDate            Genres  \
# 0  3764200  Resident Evil Requiem  game  Feb 26, 2026  Action,Adventure
#
#          Developers        Publishers  \
# 0  CAPCOM Co., Ltd.  CAPCOM Co., Ltd.
#
#                                          Description   price  \
# 0  Resident Evil Requiem Deluxe Edition Resident ...  69.99$
#
#                                            Thumbnail Tags  ReviewScore  \
# 0  https://shared.akamai.steamstatic.com/store_it...  NaN            9
#
#    PositiveReview  NegativeReview OsRequirement MemoryRequirement  \
# 0           23715             793           NaN               NaN
#
#   CpuRequirement  Rank
# 0            NaN     1

# %%
dfnew=pd.read_csv("/kaggle/input/datasets/newnguyn/steam-game-clean/SteamGames_cleaned.csv")
dfnew.head(1)
# Out:
#      Appid                   Name  Type ReleaseDate            Genres  \
# 0  3764200  Resident Evil Requiem  game  2026-02-26  Action,Adventure
#
#          Developers        Publishers  \
# 0  CAPCOM Co., Ltd.  CAPCOM Co., Ltd.
#
#                                          Description  price  \
# 0  Resident Evil Requiem Deluxe Edition Resident ...  69.99
#
#                                            Thumbnail  ... ReviewScore  \
# 0  https://shared.akamai.steamstatic.com/store_it...  ...           9
#
#    PositiveReview  NegativeReview       OsRequirement MemoryRequirement  Rank  \
# 0           23715             793  ['no requirement']               0.0     1
#
#    CPU_req  CPU_GHz  CPU_tier               tags
# 0      0.0      0.0       0.0  action, adventure
#
# [1 rows x 21 columns]

# %%
df.describe()
# Out:
#               Appid   ReviewScore  PositiveReview  NegativeReview  \
# count  2.993100e+04  29931.000000    2.993100e+04    29931.000000
# mean   1.722531e+06      6.237145    1.443837e+03      193.180849
# std    1.116414e+06      2.560245    1.368262e+04     2084.565186
# min    1.000000e+01      0.000000    0.000000e+00        0.000000
# 25%    7.511550e+05      6.000000    1.700000e+01        2.000000
# 50%    1.568970e+06      7.000000    5.900000e+01        9.000000
# 75%    2.587215e+06      8.000000    2.700000e+02       47.000000
# max    4.460980e+06      9.000000    1.214897e+06   202393.000000
#
#                Rank
# count  29931.000000
# mean    7585.978350
# std     4493.478798
# min        1.000000
# 25%     3742.000000
# 50%     7483.000000
# 75%    11224.500000
# max    16719.000000

# %%
dfnew.describe()
# Out:
#               Appid         price   ReviewScore  PositiveReview  \
# count  2.990500e+04  29905.000000  29905.000000    2.990500e+04
# mean   1.723483e+06     11.789654      6.238121    1.443402e+03
# std    1.116176e+06     12.068100      2.559259    1.368771e+04
# min    1.000000e+01      0.000000      0.000000    0.000000e+00
# 25%    7.525800e+05      3.990000      6.000000    1.700000e+01
# 50%    1.569330e+06      8.990000      7.000000    5.900000e+01
# 75%    2.587590e+06     14.990000      8.000000    2.700000e+02
# max    4.460980e+06    299.990000      9.000000    1.214897e+06
#
#        NegativeReview  MemoryRequirement          Rank       CPU_req  \
# count    29905.000000       2.986000e+04  29905.000000  29905.000000
# mean       193.137235       4.062145e+03  14967.010968      0.871426
# std       2085.337754       1.796947e+04   8639.392888      0.334733
# min          0.000000       0.000000e+00      1.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29931 entries, 0 to 29930
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Appid              29931 non-null  int64
#  1   Name               29931 non-null  object
#  2   Type               29931 non-null  object
#  3   ReleaseDate        29917 non-null  object
#  4   Genres             29518 non-null  object
#  5   Developers         29905 non-null  object
#  6   Publishers         28886 non-null  object
#  7   Description        29879 non-null  object
#  8   price              29931 non-null  object
#  9   Thumbnail          29931 non-null  object
#  10  Tags               28317 non-null  object
#  11  ReviewScore        29931 non-null  int64
#  12  PositiveReview     29931 non-null  int64
#  13  NegativeReview     29931 non-null  int64
#  14  OsRequirement      26994 non-null  object
#  15  MemoryRequirement  25947 non-null  object
# ...

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29905 entries, 0 to 29904
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Appid              29905 non-null  int64
#  1   Name               29880 non-null  object
#  2   Type               29905 non-null  object
#  3   ReleaseDate        29905 non-null  object
#  4   Genres             29499 non-null  object
#  5   Developers         29671 non-null  object
#  6   Publishers         29740 non-null  object
#  7   Description        29905 non-null  object
#  8   price              29905 non-null  float64
#  9   Thumbnail          29905 non-null  object
#  10  Tags               29676 non-null  object
#  11  ReviewScore        29905 non-null  int64
#  12  PositiveReview     29905 non-null  int64
#  13  NegativeReview     29905 non-null  int64
#  14  OsRequirement      29905 non-null  object
#  15  MemoryRequirement  29860 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Appid                   0
# Name                    0
# Type                    0
# ReleaseDate            14
# Genres                413
# Developers             26
# Publishers           1045
# Description            52
# price                   0
# Thumbnail               0
# Tags                 1614
# ReviewScore             0
# PositiveReview          0
# NegativeReview          0
# OsRequirement        2937
# MemoryRequirement    3984
# CpuRequirement       3859
# Rank                    0
# dtype: int64

# %%
dfnew.isnull().sum()
# Out:
# Appid                  0
# Name                  25
# Type                   0
# ReleaseDate            0
# Genres               406
# Developers           234
# Publishers           165
# Description            0
# price                  0
# Thumbnail              0
# Tags                 229
# ReviewScore            0
# PositiveReview         0
# NegativeReview         0
# OsRequirement          0
# MemoryRequirement     45
# Rank                   0
# CPU_req                0
# CPU_GHz                0
# CPU_tier               0
# tags                 287
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
dfnew.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Appid                0
# Name                 0
# Type                 0
# ReleaseDate          0
# Genres               0
# Developers           0
# Publishers           0
# Description          0
# price                0
# Thumbnail            0
# Tags                 0
# ReviewScore          0
# PositiveReview       0
# NegativeReview       0
# OsRequirement        0
# MemoryRequirement    0
# CpuRequirement       0
# Rank                 0
# dtype: int64

# %%
dfnew.isnull().sum()
# Out:
# Appid                0
# Name                 0
# Type                 0
# ReleaseDate          0
# Genres               0
# Developers           0
# Publishers           0
# Description          0
# price                0
# Thumbnail            0
# Tags                 0
# ReviewScore          0
# PositiveReview       0
# NegativeReview       0
# OsRequirement        0
# MemoryRequirement    0
# Rank                 0
# CPU_req              0
# CPU_GHz              0
# CPU_tier             0
# tags                 0
# dtype: int64

# %%
df.duplicated()
# Out:
# 1        False
# 2        False
# 4        False
# 5        False
# 7        False
#          ...
# 29925    False
# 29927    False
# 29928    False
# 29929    False
# 29930    False
# Length: 24395, dtype: bool

# %%
dfnew.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29900    False
# 29901    False
# 29902    False
# 29903    False
# 29904    False
# Length: 29132, dtype: bool

# %%
df['ReleaseDate'] = pd.to_datetime(df['ReleaseDate'], format='mixed', errors='coerce')

# %%
dfnew['ReleaseDate'] = pd.to_datetime(df['ReleaseDate'], format='mixed', errors='coerce')

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24395 entries, 1 to 29930
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Appid              24395 non-null  int64
#  1   Name               24395 non-null  object
#  2   Type               24395 non-null  object
#  3   ReleaseDate        24395 non-null  datetime64[ns]
#  4   Genres             24395 non-null  object
#  5   Developers         24395 non-null  object
#  6   Publishers         24395 non-null  object
#  7   Description        24395 non-null  object
#  8   price              0 non-null      float64
#  9   Thumbnail          24395 non-null  object
#  10  Tags               24395 non-null  object
#  11  ReviewScore        24395 non-null  int64
#  12  PositiveReview     24395 non-null  int64
#  13  NegativeReview     24395 non-null  int64
#  14  OsRequirement      24395 non-null  object
#  15  MemoryRequirement  24395 non-null  object
# ...

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29132 entries, 0 to 29904
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Appid              29132 non-null  int64
#  1   Name               29132 non-null  object
#  2   Type               29132 non-null  object
#  3   ReleaseDate        23741 non-null  datetime64[ns]
#  4   Genres             29132 non-null  object
#  5   Developers         29132 non-null  object
#  6   Publishers         29132 non-null  object
#  7   Description        29132 non-null  object
#  8   price              29132 non-null  float64
#  9   Thumbnail          29132 non-null  object
#  10  Tags               29132 non-null  object
#  11  ReviewScore        29132 non-null  int64
#  12  PositiveReview     29132 non-null  int64
#  13  NegativeReview     29132 non-null  int64
#  14  OsRequirement      29132 non-null  object
#  15  MemoryRequirement  29132 non-null  float64
# ...

# %%
df['Type'].unique()
# Out:
# array(['game', 'dlc', 'music', 'mod'], dtype=object)

# %%
df['Genres'].unique()
# Out:
# array(['Action,Free To Play', 'Action', 'Action,Adventure,Free To Play',
#        ...,
#        'Action,Indie,Massively Multiplayer,RPG,Simulation,Early Access',
#        'Casual,Free To Play,Simulation,Sports',
#        'Casual,Indie,Massively Multiplayer,Racing,Simulation,Sports,Early Access'],
#       dtype=object)

# %%
df['Developers'].unique()
# Out:
# array(['Valve', 'Embark Studios', 'Respawn', ..., 'Veritable Joy Studios',
#        'Kiralice Sha', 'Return To Adventure Mountain, LLC'], dtype=object)

# %%
df['Publishers'].unique()
# Out:
# array(['Valve', 'Embark Studios', 'Electronic Arts', ...,
#        'Ticking Clock Games', 'Veritable Joy Studios ',
#        'Return To Adventure Mountain, LLC'], dtype=object)

# %%
df['Tags'].unique()
# Out:
# array(['FPS,Shooter,Multiplayer,Competitive,Action,Team-Based,eSports,Tactical,First-Person,PvP,Online Co-Op,Co-op,Strategy,Military,War,Difficult,Trading,Realistic,Fast-Paced,Moddable',
#        'Extraction Shooter,Multiplayer,PvP,PvE,Third-Person Shooter,Post-apocalyptic,Shooter,Online Co-Op,Survival,Sci-fi,Atmospheric,Third Person,Crafting,Inventory Management,Action,Open World,Combat,Futuristic,Character Customization,Realistic',
#        'Free to Play,Multiplayer,Battle Royale,FPS,Shooter,First-Person,PvP,Action,Hero Shooter,Team-Based,Tactical,Sci-fi,Co-op,Loot,Survival,Character Customization,Funny,Cyberpunk,Lore-Rich,Cinematic',
#        ...,
#        'LGBTQ+,Female Protagonist,JRPG,Indie,Story Rich,Fantasy,RPG,Casual,Pixel Graphics,Exploration,Turn-Based Combat,2D,RPGMaker,Turn-Based,Cute,Party-Based RPG,Dungeon Crawler,Singleplayer,Adventure,Sexual Content',
#        'Singleplayer,RPG,2D,Fantasy,Pixel Graphics,Story Rich,Free to Play,Combat',
# ...

# %%
df['OsRequirement'].unique()
# Out:
# array(['Windows® 10', 'Windows 10 or later 64-bit (latest update)',
#        '64-bit Windows 10', ..., 'Microsoft® Windows® 10 x64',
#        'Windows® 7 / Windows Vista® / Windows® 8 / Windows® 10',
#        'Windows 7 32 Bit or higher'], dtype=object)

# %%
df['Publishers'] = df['Publishers'].str.strip()
df['Developers'] = df['Developers'].str.strip()

# %%
dfnew['Developers'].unique()
# Out:
# array(['CAPCOM Co., Ltd.', 'Valve', 'Embark Studios', ..., 'Kiralice Sha',
#        'LunaRolexLer', 'Return To Adventure Mountain, LLC'], dtype=object)

# %%
dfnew['Publishers'].unique()
# Out:
# array(['CAPCOM Co., Ltd.', 'Valve', 'Embark Studios', ...,
#        'Veritable Joy Studios', 'LunaRolexLer',
#        'Return To Adventure Mountain, LLC'], dtype=object)

# %%
df['Genres'] = df['Genres'].str.split(',')

# %%
dfnew['Genres'] = df['Genres'].str.split(',')

# %%
df = df.explode('Genres')

# %%
dfnew = dfnew.explode('Genres')

# %%
df['Type'].value_counts()
# Out:
# Type
# game     56414
# dlc      10499
# music       59
# mod         59
# Name: count, dtype: int64

# %%
dfnew['Type'].value_counts()
# Out:
# Type
# game     22350
# dlc       6526
# music      230
# mod         26
# Name: count, dtype: int64

# %%
df.max
# Out:
# <bound method DataFrame.max of          Appid                 Name  Type ReleaseDate        Genres  \
# 1          730     Counter-Strike 2  game  2012-08-21        Action
# 1          730     Counter-Strike 2  game  2012-08-21  Free To Play
# 2      1808500          ARC Raiders  game  2025-10-30        Action
# 4      1172470        Apex Legends™  game  2020-11-04        Action
# 4      1172470        Apex Legends™  game  2020-11-04     Adventure
# ...        ...                  ...   ...         ...           ...
# 29929  3956320             Inotia 4  game  2025-12-07           RPG
# 29929  3956320             Inotia 4  game  2025-12-07  Free To Play
# 29930   791180  1 Screen Platformer  game  2019-03-06        Action
# 29930   791180  1 Screen Platformer  game  2019-03-06     Adventure
# 29930   791180  1 Screen Platformer  game  2019-03-06         Indie
#
#                               Developers                         Publishers  \
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of          Appid                 Name  Type ReleaseDate        Genres  \
# 1          730     Counter-Strike 2  game  2012-08-21        Action
# 1          730     Counter-Strike 2  game  2012-08-21  Free To Play
# 2      1808500          ARC Raiders  game  2025-10-30        Action
# 4      1172470        Apex Legends™  game  2020-11-04        Action
# 4      1172470        Apex Legends™  game  2020-11-04     Adventure
# ...        ...                  ...   ...         ...           ...
# 29929  3956320             Inotia 4  game  2025-12-07           RPG
# 29929  3956320             Inotia 4  game  2025-12-07  Free To Play
# 29930   791180  1 Screen Platformer  game  2019-03-06        Action
# 29930   791180  1 Screen Platformer  game  2019-03-06     Adventure
# 29930   791180  1 Screen Platformer  game  2019-03-06         Indie
#
#                               Developers                         Publishers  \
# ...

# %%
dfnew.max()
# Out:
# Appid                                                          4460980
# Name                                                              €100
# Type                                                             music
# ReleaseDate                                        2026-05-29 00:00:00
# Genres                                                            None
# Developers                                                           ∇
# Publishers                                                           ∇
# Description          ⏹ Summary It has been several hundred years si...
# price                                                           299.99
# Thumbnail                                                           {}
# Tags                 Zombies,VR,Violent,Gore,Action,Indie,RPG,Shoot...
# ReviewScore                                                          9
# PositiveReview                                                 1214897
# ...

# %%
dfnew.min
# Out:
# <bound method DataFrame.min of          Appid                                    Name  Type ReleaseDate  \
# 0      3764200                   Resident Evil Requiem  game         NaT
# 1          730                        Counter-Strike 2  game  2012-08-21
# 2      1808500                             ARC Raiders  game  2025-10-30
# 3       359550          Tom Clancy's Rainbow Six Siege  game         NaT
# 4      1172470                           Apex Legends™  game  2020-11-04
# ...        ...                                     ...   ...         ...
# 29900   843170                                ILLUSION  game         NaT
# 29901  1308250                      Knight Bewitched 2  game  2018-12-07
# 29902  1729610  Redmatch 2 - Fashionable Attire Bundle   dlc  2021-11-09
# 29903  3956320                                Inotia 4  game  2024-03-23
# 29904   791180                     1 Screen Platformer  game         NaT
#
#       Genres                         Developers  \
# ...

# %%
df.shape
# Out:
# (67031, 18)

# %%
dfnew.shape
# Out:
# (29132, 21)

# %%
df.to_csv("Steam_Game_MetaData.csv", index=False)

# %%
df.to_excel("Steam_Game_MetaData.xlsx", index=False)

# %%
dfnew.to_csv("Steam_Game_cleaned.csv", index=False)

# %%
dfnew.to_excel("Steam_Game_cleaned.xlsx", index=False)
