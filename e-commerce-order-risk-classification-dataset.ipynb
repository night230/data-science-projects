# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/emirhanakku/e-commerce-order-risk-classification-dataset/synthetic_ecommerce_order_risk_dataset.csv

# %%
import numpy as np 
import pandas as pd
import os

df=pd.read_csv("/kaggle/input/datasets/emirhanakku/e-commerce-order-risk-classification-dataset/synthetic_ecommerce_order_risk_dataset.csv")
df.head(1)
# Out:
#           order_id  order_date  country device_type traffic_source  \
# 0  ORD-2024-001936  2024-01-03  Belgium      Mobile       Paid Ads
#
#   payment_method product_category  customer_age_days  previous_orders  \
# 0    Credit Card           Sports                381                3
#
#    avg_order_value_eur  ...  shipping_distance_km  delivery_days_estimated  \
# 0                28.66  ...                 105.7                        5
#
#    late_delivery_risk  address_mismatch  high_risk_ip  \
# 0                   0                 0             0
#
#    customer_support_contacts  review_score  is_returned  is_fraud  risk_label
# 0                          0           4.4            0         0      Normal
#
# [1 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   order_id                   12000 non-null  object
#  1   order_date                 12000 non-null  object
#  2   country                    12000 non-null  object
#  3   device_type                12000 non-null  object
#  4   traffic_source             12000 non-null  object
#  5   payment_method             12000 non-null  object
#  6   product_category           12000 non-null  object
#  7   customer_age_days          12000 non-null  int64
#  8   previous_orders            12000 non-null  int64
#  9   avg_order_value_eur        12000 non-null  float64
#  10  order_value_eur            12000 non-null  float64
#  11  quantity                   12000 non-null  int64
#  12  discount_rate              12000 non-null  float64
# ...

# %%
df.tail(1)
# Out:
#               order_id  order_date      country device_type  traffic_source  \
# 11999  ORD-2024-007271  2024-05-23  Netherlands     Desktop  Organic Search
#
#       payment_method product_category  customer_age_days  previous_orders  \
# 11999         PayPal           Beauty                288                2
#
#        avg_order_value_eur  ...  shipping_distance_km  \
# 11999                35.58  ...                 406.6
#
#        delivery_days_estimated  late_delivery_risk  address_mismatch  \
# 11999                        3                   0                 0
#
#        high_risk_ip  customer_support_contacts  review_score  is_returned  \
# 11999             0                          1           3.7            0
#
#        is_fraud  risk_label
# 11999         0      Normal
#
# [1 rows x 23 columns]

# %%
df.describe()
# Out:
#        customer_age_days  previous_orders  avg_order_value_eur  \
# count       12000.000000     12000.000000         12000.000000
# mean          352.789083         1.943417            48.940278
# std           237.556088         1.902590            28.716864
# min             5.000000         0.000000             8.000000
# 25%           177.000000         1.000000            29.070000
# 50%           299.000000         1.000000            42.100000
# 75%           475.000000         3.000000            61.010000
# max          1832.000000        13.000000           350.450000
#
#        order_value_eur      quantity  discount_rate  shipping_distance_km  \
# count     12000.000000  12000.000000   12000.000000          12000.000000
# mean         61.053339      2.171833       0.146857            479.196567
# std          55.540429      1.625534       0.113934            330.305205
# min           5.000000      1.000000       0.000000              5.000000
# ...

# %%
df.isnull().sum()
# Out:
# order_id                     0
# order_date                   0
# country                      0
# device_type                  0
# traffic_source               0
# payment_method               0
# product_category             0
# customer_age_days            0
# previous_orders              0
# avg_order_value_eur          0
# order_value_eur              0
# quantity                     0
# discount_rate                0
# shipping_distance_km         0
# delivery_days_estimated      0
# late_delivery_risk           0
# address_mismatch             0
# high_risk_ip                 0
# customer_support_contacts    0
# review_score                 0
# is_returned                  0
# is_fraud                     0
# risk_label                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11995    False
# 11996    False
# 11997    False
# 11998    False
# 11999    False
# Length: 12000, dtype: bool

# %%
df.dropna()
# Out:
#               order_id  order_date      country device_type  traffic_source  \
# 0      ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1      ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2      ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
# 3      ORD-2024-009121  2024-05-28  Netherlands      Mobile  Organic Search
# 4      ORD-2025-000361  2025-01-31  Netherlands     Desktop          Direct
# ...                ...         ...          ...         ...             ...
# 11995  ORD-2023-011965  2023-02-19       France      Mobile    Social Media
# 11996  ORD-2023-005192  2023-05-12       France      Mobile  Organic Search
# 11997  ORD-2024-005391  2024-06-13      Germany      Mobile  Organic Search
# 11998  ORD-2025-000861  2025-04-04       Poland     Desktop     Marketplace
# 11999  ORD-2024-007271  2024-05-23  Netherlands     Desktop  Organic Search
#
# ...

# %%
df.fillna(0)
# Out:
#               order_id  order_date      country device_type  traffic_source  \
# 0      ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1      ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2      ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
# 3      ORD-2024-009121  2024-05-28  Netherlands      Mobile  Organic Search
# 4      ORD-2025-000361  2025-01-31  Netherlands     Desktop          Direct
# ...                ...         ...          ...         ...             ...
# 11995  ORD-2023-011965  2023-02-19       France      Mobile    Social Media
# 11996  ORD-2023-005192  2023-05-12       France      Mobile  Organic Search
# 11997  ORD-2024-005391  2024-06-13      Germany      Mobile  Organic Search
# 11998  ORD-2025-000861  2025-04-04       Poland     Desktop     Marketplace
# 11999  ORD-2024-007271  2024-05-23  Netherlands     Desktop  Organic Search
#
# ...

# %%
df.dropna()
# Out:
#               order_id  order_date      country device_type  traffic_source  \
# 0      ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1      ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2      ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
# 3      ORD-2024-009121  2024-05-28  Netherlands      Mobile  Organic Search
# 4      ORD-2025-000361  2025-01-31  Netherlands     Desktop          Direct
# ...                ...         ...          ...         ...             ...
# 11995  ORD-2023-011965  2023-02-19       France      Mobile    Social Media
# 11996  ORD-2023-005192  2023-05-12       France      Mobile  Organic Search
# 11997  ORD-2024-005391  2024-06-13      Germany      Mobile  Organic Search
# 11998  ORD-2025-000861  2025-04-04       Poland     Desktop     Marketplace
# 11999  ORD-2024-007271  2024-05-23  Netherlands     Desktop  Organic Search
#
# ...

# %%
df['customer_age_days'].describe()
# Out:
# count    12000.000000
# mean       352.789083
# std        237.556088
# min          5.000000
# 25%        177.000000
# 50%        299.000000
# 75%        475.000000
# max       1832.000000
# Name: customer_age_days, dtype: float64

# %%
df.max()
# Out:
# order_id                     ORD-2025-012000
# order_date                        2025-12-31
# country                               Turkey
# device_type                           Tablet
# traffic_source                  Social Media
# payment_method                        PayPal
# product_category                        Toys
# customer_age_days                       1832
# previous_orders                           13
# avg_order_value_eur                   350.45
# order_value_eur                       810.75
# quantity                                   8
# discount_rate                           0.75
# shipping_distance_km                  2589.7
# delivery_days_estimated                    9
# late_delivery_risk                         1
# address_mismatch                           1
# high_risk_ip                               1
# customer_support_contacts                  5
# review_score                             5.0
# is_returned                                1
# ...

# %%
df.mean
# Out:
# <bound method DataFrame.mean of               order_id  order_date      country device_type  traffic_source  \
# 0      ORD-2024-001936  2024-01-03      Belgium      Mobile        Paid Ads
# 1      ORD-2025-006495  2025-11-26  Netherlands     Desktop           Email
# 2      ORD-2023-001721  2023-11-07  Netherlands      Mobile  Organic Search
# 3      ORD-2024-009121  2024-05-28  Netherlands      Mobile  Organic Search
# 4      ORD-2025-000361  2025-01-31  Netherlands     Desktop          Direct
# ...                ...         ...          ...         ...             ...
# 11995  ORD-2023-011965  2023-02-19       France      Mobile    Social Media
# 11996  ORD-2023-005192  2023-05-12       France      Mobile  Organic Search
# 11997  ORD-2024-005391  2024-06-13      Germany      Mobile  Organic Search
# 11998  ORD-2025-000861  2025-04-04       Poland     Desktop     Marketplace
# 11999  ORD-2024-007271  2024-05-23  Netherlands     Desktop  Organic Search
#
# ...

# %%
df['country'].unique()
df['device_type'].unique()
# Out:
# array(['Mobile', 'Desktop', 'Tablet'], dtype=object)

# %%
df['order_date']
# Out:
# 0        2024-01-03
# 1        2025-11-26
# 2        2023-11-07
# 3        2024-05-28
# 4        2025-01-31
#             ...
# 11995    2023-02-19
# 11996    2023-05-12
# 11997    2024-06-13
# 11998    2025-04-04
# 11999    2024-05-23
# Name: order_date, Length: 12000, dtype: object

# %%
df['is_fraud'].unique()
# Out:
# array([0, 1])

# %%
df['customer_age_days'].describe()
# Out:
# count    12000.000000
# mean       352.789083
# std        237.556088
# min          5.000000
# 25%        177.000000
# 50%        299.000000
# 75%        475.000000
# max       1832.000000
# Name: customer_age_days, dtype: float64

# %%
df['review_score'].unique()
# Out:
# array([4.4, 4.8, 3.3, 4.2, 5. , 3.7, 4.5, 4.6, 3.4, 3.9, 4.3, 3.5, 4.9,
#        4. , 3.8, 4.7, 2.2, 4.1, 3.6, 3. , 3.2, 2.6, 2.4, 2.8, 2.7, 3.1,
#        2.3, 1.9, 2.9, 1.7, 1.3, 2.1, 2.5, 2. , 1.8, 1.4])

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   order_id                   12000 non-null  object
#  1   order_date                 12000 non-null  datetime64[ns]
#  2   country                    12000 non-null  object
#  3   device_type                12000 non-null  object
#  4   traffic_source             12000 non-null  object
#  5   payment_method             12000 non-null  object
#  6   product_category           12000 non-null  object
#  7   customer_age_days          12000 non-null  int64
#  8   previous_orders            12000 non-null  int64
#  9   avg_order_value_eur        12000 non-null  float64
#  10  order_value_eur            12000 non-null  float64
#  11  quantity                   12000 non-null  int64
#  12  discount_rate              12000 non-null  float64
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['review_score'] = df['review_score'].round(1)

# %%
df.to_csv("E-Commerce Order Risk Classification Dataset", index=False)

# %%
df.to_excel("E-Commerce Order Risk Classification Dataset.xlsx", index=False)

# %%
df.head(5)
# Out:
#           order_id order_date      country device_type  traffic_source  \
# 0  ORD-2024-001936 2024-01-03      Belgium      Mobile        Paid Ads
# 1  ORD-2025-006495 2025-11-26  Netherlands     Desktop           Email
# 2  ORD-2023-001721 2023-11-07  Netherlands      Mobile  Organic Search
# 3  ORD-2024-009121 2024-05-28  Netherlands      Mobile  Organic Search
# 4  ORD-2025-000361 2025-01-31  Netherlands     Desktop          Direct
#
#   payment_method product_category  customer_age_days  previous_orders  \
# 0    Credit Card           Sports                381                3
# 1     Debit Card           Garden                561                6
# 2     Debit Card           Garden                324                2
# 3         Klarna      Electronics                378                3
# 4  Bank Transfer   Home & Kitchen                447                5
#
#    avg_order_value_eur  ...  shipping_distance_km  delivery_days_estimated  \
# ...
